# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cms = [
    np.array([[3440, 530],
              [687, 3593]]),
    np.array([[3204, 766],
              [625, 3655]]),
    np.array([[3260, 710],
              [671, 3609]]),
    np.array([[3542, 428],
              [120, 4160]])
]

titles = ['Gradient boosting', 'Linear SVM', 'Logistic Regression', 'Random Forest']

plt.rcParams.update({
    'font.family': 'DejaVu Sans',
    'axes.titlesize': 20,
    'axes.labelsize': 20,
    'xtick.labelsize': 20,
    'ytick.labelsize': 20
})

fig, axes = plt.subplots(1, 4, figsize=(20, 4))

for i, ax in enumerate(axes):
    cm = cms[i]
    cm_sum = cm.sum(axis=1)[:, np.newaxis]
    cm_perc = cm / cm_sum * 100
    
    # Base heatmap (no annotations yet)
    sns.heatmap(cm, cmap='Blues', cbar=True, ax=ax,
                linewidths=1, linecolor='black', square=True)

    # Add custom annotations with dynamic color
    threshold = cm.max() / 2

    for y in range(cm.shape[0]):
        for x in range(cm.shape[1]):
            value = cm[y, x]
            percent = cm_perc[y, x]
            color = "white" if value > threshold else "black"
            
            ax.text(x + 0.5, y + 0.5,
                    f"{value}\n{percent:.1f}%",
                    ha='center', va='center',
                    fontsize=14,
                    color=color)

    ax.set_title(titles[i])
    ax.set_xlabel('Predicted label')
    ax.set_ylabel('True label')

plt.tight_layout()
plt.savefig("confusion_matrices_unknown_muts_only.png", width=18, height=6, dpi=400, bbox_inches='tight')
plt.show()
# Out:
# /Users/alfred/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:53: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "width" which is no longer supported as of 3.3 and will become an error in 3.6
# /Users/alfred/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:53: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "height" which is no longer supported as of 3.3 and will become an error in 3.6

# %%
# all mutations CMs
cms = [
    np.array([[3468, 502],
              [597, 3683]]),
    np.array([[3160, 810],
              [507, 3773]]),
    np.array([[3258, 712],
              [587, 3693]]),
    np.array([[3544, 426],
              [102, 4178]])
]

titles = ['Gradient boosting', 'Linear SVM', 'Logistic Regression', 'Random Forest']

plt.rcParams.update({
    'font.family': 'DejaVu Sans',
    'axes.titlesize': 20,
    'axes.labelsize': 20,
    'xtick.labelsize': 20,
    'ytick.labelsize': 20
})

fig, axes = plt.subplots(1, 4, figsize=(20, 4))

for i, ax in enumerate(axes):
    cm = cms[i]
    cm_sum = cm.sum(axis=1)[:, np.newaxis]
    cm_perc = cm / cm_sum * 100
    
    # Base heatmap (no annotations yet)
    sns.heatmap(cm, cmap='Blues', cbar=True, ax=ax,
                linewidths=1, linecolor='black', square=True)

    # Add custom annotations with dynamic color
    threshold = cm.max() / 2

    for y in range(cm.shape[0]):
        for x in range(cm.shape[1]):
            value = cm[y, x]
            percent = cm_perc[y, x]
            color = "white" if value > threshold else "black"
            
            ax.text(x + 0.5, y + 0.5,
                    f"{value}\n{percent:.1f}%",
                    ha='center', va='center',
                    fontsize=14,
                    color=color)

    ax.set_title(titles[i])
    ax.set_xlabel('Predicted label')
    ax.set_ylabel('True label')

plt.tight_layout()
plt.savefig("confusion_matrices_all_muts.png", width=18, height=6, dpi=400, bbox_inches='tight')
plt.show()
# Out:
# /Users/alfred/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:54: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "width" which is no longer supported as of 3.3 and will become an error in 3.6
# /Users/alfred/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:54: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "height" which is no longer supported as of 3.3 and will become an error in 3.6
